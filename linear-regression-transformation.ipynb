# %% [markdown]
# <a href="https://www.kaggle.com/code/pyliraghuram/linear-regression-transformation?scriptVersionId=144346588" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/insurance-premium-prediction/insurance.csv')
df.head(4)

# %%
df['children'] = df['children'].astype('object')

# %%
plt.figure(figsize = (12,8))
sns.histplot(x= 'expenses',data = df,kde = True)

# %%
#df['expenses'] = np.sqrt(df['expenses'])

# %%
df.head(4)

# %%
plt.figure(figsize = (12,8))
sns.histplot(x= 'expenses',data = df,kde = True)

# %%
df['expenses'] = np.log(df['expenses'])

# %%
plt.figure(figsize = (12,8))
sns.histplot(x= 'expenses',data = df,kde = True)

# %%
cat_columns = df.select_dtypes(include = 'object').columns
cat_columns

# %%
df  = pd.get_dummies(df,cat_columns,drop_first = True)

# %%
y = df['expenses']

# %%
X = df[['age', 'bmi', 'sex_male', 'children_1', 'children_2',
       'children_3', 'children_4', 'children_5', 'smoker_yes',
       'region_northwest', 'region_southeast', 'region_southwest']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=410)

# %%
from sklearn.linear_model import LinearRegression

lm = LinearRegression()
lm.fit(X_train,y_train)

# %%
predictions = lm.predict(X_test)
predictions

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

# %%
from sklearn.metrics import r2_score
r2_score(y_test, predictions)*100
