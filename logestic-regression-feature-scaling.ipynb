# %% [markdown]
# <a href="https://www.kaggle.com/code/pyliraghuram/logestic-regression-feature-scaling?scriptVersionId=144346770" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/social-network-/Social_Network_Ads.csv')
df.head(4)

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
for i in df.columns :
    print('*'*30)
    print(i)
    print(df[i].unique())

# %% [markdown]
# # EDA

# %%
sns.countplot(x = 'Purchased',data = df)

# %%
sns.countplot(x ='Gender',data = df )

# %%
sns.histplot(x = 'User ID',data = df,kde = True)

# %%
sns.barplot(data = df,hue = 'User ID',x =  'Purchased')

# %%
sns.boxplot(data = df,x = 'User ID',hue =  'Purchased')

# %%
sns.histplot(x = 'Age',data = df,kde = True)

# %%
sns.barplot(data = df,x =  'Purchased',y='Age')

# %%
sns.histplot(x = 'EstimatedSalary',data = df,kde = True)

# %%
sns.barplot(y = 'EstimatedSalary',data = df,x =  'Purchased')

# %%
sns.pairplot(data=df)

# %%
df.describe()

# %%
df.describe(include = 'O')

# %%
sns.heatmap(df.corr(),annot = True)

# %%
df.drop('User ID',axis = 1,inplace = True)

# %%
df.head()

# %%
sns.heatmap(df.corr(),annot = True)

# %% [markdown]
# # ***Data Split
# **test & train**

# %%
y = df['Purchased']
y

# %%
X = df.drop('Purchased',axis = 1)
X

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state = 2)

# %%
X_train

# %%
X_test

# %% [markdown]
# # Label transformation

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X_train['Gender'] = le.fit_transform(X_train['Gender'])
X_test['Gender'] = le.transform(X_test['Gender'])

# %%
print(X_train)

# %%
print(X_test)

# %% [markdown]
# # ***Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

#from sklearn.preprocessing import Normalizer
 
ssc = StandardScaler()
X_train[['ScaledSalary']]= ssc.fit_transform(X_train[['EstimatedSalary']])
#X_test['EstimatedSalary'] = ssc.transform(X_test['EstimatedSalary'])
X_test[['ScaledSalary']]= ssc.fit_transform(X_test[['EstimatedSalary']])

# %%
X_train

# %% [markdown]
# # Train the model

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score
log = LogisticRegression()
log.fit(X_train,y_train)

# %% [markdown]
# # ERROR ????¶

# %%
print(log.score(X_train,y_train)*100)

# %%
predictions = log.predict(X_test)
predictions

# %%
print('train analysis',log.score(X_train,y_train)*100)
print('test analysis',log.score(X_test,y_test)*100)

# %%
log.coef_

# %%
from sklearn.metrics import confusion_matrix, classification_report
cm = confusion_matrix(y_test, predictions)
cm

# %%
print("Accuracy:",(cm[0, 0] + cm[1, 1]) / np.sum(cm))
print("Precision:", cm[1, 1] / (cm[1, 1] + cm[0, 1]))
print("Recall (Sensitivity):",cm[1, 1] / (cm[1, 1] + cm[1, 0]))
print("Specificity:", cm[0, 0] / (cm[0, 0] + cm[0, 1]))
