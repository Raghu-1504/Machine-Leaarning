# %% [markdown]
# <a href="https://www.kaggle.com/code/pyliraghuram/titanic-explotary-data-analysis?scriptVersionId=144346399" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('/kaggle/input/titanic-datasetcsv/titanic_dataset.csv')
df.head(4)

# %%
df['survived'].value_counts(dropna = False)

# %%
df.info()

# %%
df.shape

# %%
df.duplicated().value_counts()

# %%
df.drop_duplicates(inplace= True)
df.shape

# %%
df.describe()

# %%
df.describe(include = object).T

# %%
df.isnull().sum()/len(df)*100

# %%
doc = df.loc[:,df.dtypes == object].columns
doc

# %%
for i in doc:
        print(i)
        print('*'*10)
        print(df[i].value_counts())
        print('*'*10)

# %% [markdown]
# # 	survived

# %%
sns.countplot(x = 'survived',data = df)

# %%
df['survived'].value_counts()/len(df)*100

# %%
plt.figure(figsize=(12,6))

plt.pie(df['survived'].value_counts()/len(df)*100,labels=["0","1"],
        autopct="%.1f%%",
        explode=[0,0.1],
        colors=["lightskyblue","gold"],
        textprops=({'size': 'x-large'}),
        shadow=True);
plt.title("Percentage of survivals",fontsize=15)

# %% [markdown]
# # pclass

# %%
df.columns

# %%
df['pclass'].unique()

# %%
df['pclass'].value_counts(dropna = False)

# %%
sns.countplot(x = 'pclass',data = df)

# %%
plt.pie(x = df['pclass'].value_counts(),data = df,labels=['1','2','3'],autopct="%.1f%%",
        explode=[0,0.01,0.02],textprops=({'size': 'x-large'}),shadow=True)
plt.title("Percentage of plass",fontsize=15);

# %%
fig,ax = plt.subplots(figsize=(12,6))

sns.countplot(x="pclass",data=df,hue="survived")

# %%
df.groupby("pclass")["survived"].value_counts(normalize = True)*100

# %%
fig,(ax1,ax2,ax3)= plt.subplots(ncols = 3,figsize = (12,6))
ax1.pie(x = (df.groupby("pclass")["survived"].value_counts(normalize = True)*100)[:2],explode = [0,.01],labels=["1", "0"] ,data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax2.pie(x = (df.groupby("pclass")["survived"].value_counts(normalize = True)*100)[2:4],explode = [0,.01],labels=["1", "0"] ,data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax3.pie(x = (df.groupby("pclass")["survived"].value_counts(normalize = True)*100)[4:],explode = [0,.01],labels=["1", "0"] ,data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax1.set_title("class_1")
ax2.set_title("class_2")
ax3.set_title("class_3")

# %% [markdown]
# people from c1 survived more and less from c3

# %% [markdown]
# # SEX

# %%
df.columns

# %%
print(df['sex'].unique())
df['sex'].value_counts(normalize = True)*100

# %%
fig,ax = plt.subplots(figsize=(12,6))
sns.countplot(x = 'sex',data = df)

# %%
fig,ax = plt.subplots(figsize=(12,6))
sns.countplot(x = 'who',data = df)

# %%
plt.pie(df['sex'].value_counts(normalize = True)*100,data = df,explode = [0,.01],labels=["male", "female"] ,textprops= {"fontsize":12},autopct= "%.2f%%")

# %%
sns.countplot(x = 'sex',data = df,hue = 'survived')

# %%
df.groupby('sex')['survived'].value_counts(normalize = True)*100

# %%
fig,(ax1,ax2)= plt.subplots(ncols = 2,figsize = (12,6))
ax1.pie(x = (df.groupby('sex')['survived'].value_counts(normalize = True)*100)[0:2],explode = [0,.01],labels=["1", "0"] ,data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax2.pie(x = (df.groupby("sex")["survived"].value_counts(normalize = True)*100)[2:],explode = [0,.01],labels=["0", "1"] ,data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax1.set_title("female")
ax2.set_title("male")

# %% [markdown]
# most survived are female and most dead are male

# %% [markdown]
# # WHO

# %%
df.columns

# %%
df['who'].unique()

# %%
df['who'].value_counts(normalize = True)*100

# %%
sns.countplot(x = 'who',data  = df)

# %%
plt.pie(df['who'].value_counts(normalize = True)*100,data = df,explode = [0,.01,0.01],labels=['man', 'woman', 'child'],textprops= {"fontsize":12},autopct= "%.2f%%")

# %%
df.groupby('who')['survived'].value_counts(normalize = True)*100

# %%
sns.countplot(x  ='who',data = df,hue = 'survived')

# %%
fig,(ax1,ax2,ax3)= plt.subplots(ncols = 3,figsize = (12,6))
ax1.pie(x = (df.groupby("who")["survived"].value_counts(normalize = True)*100)[:2],explode = [0,.01],labels=["1", "0"] ,data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax2.pie(x = (df.groupby("who")["survived"].value_counts(normalize = True)*100)[2:4],explode = [0,.01],labels=["0", "1"] ,data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax3.pie(x = (df.groupby("who")["survived"].value_counts(normalize = True)*100)[4:],explode = [0,.01],labels=["1", "0"] ,data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax1.set_title("child")
ax2.set_title("man")
ax3.set_title("woman")

# %% [markdown]
# most survived are women and then child most dead are man

# %% [markdown]
# # class

# %%
df.columns

# %%
df['class'].unique()

# %%
df['class'].value_counts(normalize = True)*100

# %%
sns.countplot(x = 'class',data = df)

# %%
plt.pie(df['class'].value_counts(normalize = True)*100,data = df,explode = [0,.01,.01],labels=['Third', 'First', 'Second'],textprops= {"fontsize":12},autopct= "%.2f%%")

# %%
df.groupby('class')['survived'].value_counts(normalize = True)*100

# %%
sns.countplot(x='class',data = df,hue = 'survived')

# %%
fig,(ax1,ax2,ax3) = plt.subplots(figsize  =(12,6),ncols = 3)
ax1.pie(x =(df.groupby('class')['survived'].value_counts(normalize = True)*100)[:2],explode = [0,.01],labels = ['1','0'],data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax2.pie(x =(df.groupby('class')['survived'].value_counts(normalize = True)*100)[2:4],explode = [0,.01],labels = ['1','0'],data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax3.pie(x =(df.groupby('class')['survived'].value_counts(normalize = True)*100)[4:],explode = [0,.01],labels = ['0','1'],data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax3.set_title("third_class")
ax2.set_title("second_class")
ax1.set_title("first_class")

# %% [markdown]
# most survived are 1st>2nd>3rd

# %% [markdown]
# # EMBARKED &&  EMBARK_TOWN

# %%
df.columns

# %%
df['embarked'].unique()

# %%
sns.countplot(x  ='embarked',data = df)

# %%
df.groupby('embarked')['survived'].value_counts(normalize = True)*100

# %%
df.groupby('embark_town')['survived'].value_counts(normalize = True)*100

# %%
sns.countplot(x  ='embarked',data = df,hue = 'survived')

# %%
sns.countplot(x  ='embark_town',data = df,hue = 'embark_town')#,color = ('red','blue','pink'))

# %%
df['embarked'].value_counts()

# %%
sns.countplot(x  ='embarked',data = df,hue = 'embark_town')

# %%
fig,(ax1,ax2,ax3) = plt.subplots(figsize  =(12,6),ncols = 3)
ax1.pie(x =(df.groupby('embarked')['survived'].value_counts(normalize = True)*100)[:2],explode = [0,.01],labels = ['1','0'],data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax2.pie(x =(df.groupby('embarked')['survived'].value_counts(normalize = True)*100)[2:4],explode = [0,.01],labels = ['0','1'],data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax3.pie(x =(df.groupby('embarked')['survived'].value_counts(normalize = True)*100)[4:],explode = [0,.01],labels = ['0','1'],data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax3.set_title("Cherbourg")
ax2.set_title("Queenstowns")
ax1.set_title("Southamptons")

# %%
fig,(ax1,ax2,ax3) = plt.subplots(figsize  =(12,6),ncols = 3)
ax1.pie(x =(df.groupby('embark_town')['survived'].value_counts(normalize = True)*100)[:2],explode = [0,.01],labels = ['1','0'],data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax2.pie(x =(df.groupby('embark_town')['survived'].value_counts(normalize = True)*100)[2:4],explode = [0,.01],labels = ['0','1'],data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax3.pie(x =(df.groupby('embark_town')['survived'].value_counts(normalize = True)*100)[4:],explode = [0,.01],labels = ['0','1'],data = df,textprops= {"fontsize":12},autopct= "%.2f%%")
ax3.set_title("C")
ax2.set_title("Q")
ax1.set_title("S")

# %% [markdown]
# # DECK

# %%
df.columns

# %%
df['deck'].unique()

# %%
sns.countplot(x = 'deck',data = df)

# %%
plt.pie(x= df['deck'].value_counts(normalize = True),data = df,labels =[ 'C', 'E', 'G', 'D', 'A', 'B', 'F'],explode = [.01,.1,.01,.01,.1,.1,.01],textprops= {"fontsize":12},autopct= "%.2f%%")

# %%
df['deck'].value_counts(normalize = True)*100

# %%
(df.groupby('deck')['survived'].value_counts(normalize = True)*100)

# %%
sns.countplot(x = 'deck',data = df,hue = 'survived')

# %%
(df.groupby('survived')['deck'].value_counts(normalize = True)*100)

# %%
sns.countplot(x = 'survived',hue ='deck',data = df)

# %%
fig,(ax1,ax2,ax3,ax4,ax5,ax6,ax7) = plt.subplots(ncols = 7,figsize  =(20,10))
ax1.pie(x =(df.groupby('deck')['survived'].value_counts(normalize = True)*100)[0:2],explode = [0,.01],labels = ['0','1'],data = df,textprops= {"fontsize":8},autopct= "%.2f%%")
ax2.pie(x =(df.groupby('deck')['survived'].value_counts(normalize = True)*100)[2:4],explode = [0,.01],labels = ['1','0'],data = df,textprops= {"fontsize":8},autopct= "%.2f%%")
ax3.pie(x =(df.groupby('deck')['survived'].value_counts(normalize = True)*100)[4:6],explode = [0,.01],labels = ['1','0'],data = df,textprops= {"fontsize":8},autopct= "%.2f%%")
ax4.pie(x =(df.groupby('deck')['survived'].value_counts(normalize = True)*100)[6:8],explode = [0,.01],labels = ['1','0'],data = df,textprops= {"fontsize":8},autopct= "%.2f%%")
ax5.pie(x =(df.groupby('deck')['survived'].value_counts(normalize = True)*100)[8:10],explode = [0,.01],labels = ['1','0'],data = df,textprops= {"fontsize":8},autopct= "%.2f%%")
ax6.pie(x =(df.groupby('deck')['survived'].value_counts(normalize = True)*100)[10:12],explode = [0,.01],labels = ['1','0'],data = df,textprops= {"fontsize":8},autopct= "%.2f%%")
ax7.pie(x =(df.groupby('deck')['survived'].value_counts(normalize = True)*100)[12:],explode = [0,.01],labels = ['0','1'],data = df,textprops= {"fontsize":8},autopct= "%.2f%%")


ax1.set_title("A")
ax2.set_title("B")
ax3.set_title("C")
ax4.set_title("D")
ax5.set_title("E")
ax6.set_title("F")
ax7.set_title("G")

# %% [markdown]
# B>C>D>E>F>A>G

# %%
import matplotlib.pyplot as plt
#fig,(ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9) = plt.subplots(nrows = 3,ncols = 3,figsize  =(20,10))
fig,axes = plt.subplots(nrows = 3,ncols = 3,figsize  =(15,10))
axes[0,0].pie(x =(df.groupby('deck')['survived'].value_counts(normalize = True)*100)[0:2],explode = [0,.01],labels = ['0','1'],data = df,textprops= {"fontsize":8},autopct= "%.2f%%")
axes[0,1].pie(x =(df.groupby('deck')['survived'].value_counts(normalize = True)*100)[2:4],explode = [0,.01],labels = ['1','0'],data = df,textprops= {"fontsize":8},autopct= "%.2f%%")
axes[0,2].pie(x =(df.groupby('deck')['survived'].value_counts(normalize = True)*100)[4:6],explode = [0,.01],labels = ['1','0'],data = df,textprops= {"fontsize":8},autopct= "%.2f%%")
axes[1,0].pie(x =(df.groupby('deck')['survived'].value_counts(normalize = True)*100)[6:8],explode = [0,.01],labels = ['1','0'],data = df,textprops= {"fontsize":8},autopct= "%.2f%%")
axes[1,1].pie(x =(df.groupby('deck')['survived'].value_counts(normalize = True)*100)[8:10],explode = [0,.01],labels = ['1','0'],data = df,textprops= {"fontsize":8},autopct= "%.2f%%")
axes[1,2].pie(x =(df.groupby('deck')['survived'].value_counts(normalize = True)*100)[10:12],explode = [0,.01],labels = ['1','0'],data = df,textprops= {"fontsize":8},autopct= "%.2f%%")
axes[2,0].pie(x =(df.groupby('deck')['survived'].value_counts(normalize = True)*100)[12:],explode = [0,.01],labels = ['0','1'],data = df,textprops= {"fontsize":8},autopct= "%.2f%%")


ax1.set_title("A")
ax2.set_title("B")
ax3.set_title("C")
ax4.set_title("D")
ax5.set_title("E")
ax6.set_title("F")
ax7.set_title("G")

# %% [markdown]
# # ADULT_MALE

# %%
df.columns

# %%
df['adult_male'].unique()

# %%
sns.countplot(x = 'adult_male',data = df)

# %%
df['adult_male'].value_counts(normalize = True)*100

# %%
plt.pie((df['adult_male'].value_counts(normalize = True)*100),data = df,explode = [0,.01],labels = ['male','child'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")

# %%
df.groupby('adult_male')['survived'].value_counts(normalize = True)*100

# %%
sns.countplot(x = 'adult_male',hue = 'survived',data = df)

# %%
df.groupby('adult_male')['survived'].value_counts(normalize = True)*100

# %%
fig,(ax1,ax2) = plt.subplots(ncols = 2,figsize  =(20,10))
ax1.pie((df.groupby('adult_male')['survived'].value_counts(normalize = True)*100)[:2],data = df,explode = [0,.01],labels = ['child_survived','child_death'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax2.pie((df.groupby('adult_male')['survived'].value_counts(normalize = True)*100)[2:],data = df,explode = [0,.01],labels = ['adult_male_death','adult_male_survived'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
print (ax1)
ax1.set_title("not a adult male")
#(child)")
ax2.set_title("adult male")

# %%
df.groupby('survived')['adult_male'].value_counts(normalize = True)*100

# %%
fig,(ax1,ax2) = plt.subplots(ncols = 2,figsize  =(20,10))
ax1.pie((df.groupby('survived')['adult_male'].value_counts(normalize = True)*100)[:2],data = df,explode = [0,.01],labels = ['adult male','child'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax2.pie((df.groupby('survived')['adult_male'].value_counts(normalize = True)*100)[2:],data = df,explode = [0,.01],labels = ['child','adult_male'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
print (ax1)
ax1.set_title("Dead")
#(child)")
ax2.set_title("survived")

# %% [markdown]
# most dead are adult male and most survived are child

# %% [markdown]
# # Alive
# (both alive and survived are same )

# %%
df['alive'].unique()

# %%
print(df['alive'].value_counts(dropna = False))
print(df['survived'].value_counts(dropna = False))

# %%
sns.countplot(x = 'alive',data = df)

# %%
plt.pie(df['alive'].value_counts(dropna = False),data = df,explode = [0,.01],labels = ['no', 'yes'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")

# %%
df.columns

# %%
df['alone'].unique()

# %%
print(df['alone'].value_counts(dropna = False))

# %%
sns.countplot(x = 'alone',data = df)

# %%
plt.pie(df['alone'].value_counts(),data = df,explode = [0,.01],labels = [  'True','False'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")

# %%
df.groupby('alone')['survived'].value_counts(normalize = True)*100

# %%
fig,(ax1,ax2) = plt.subplots(ncols = 2,figsize  =(20,10))
ax1.pie((df.groupby('alone')['survived'].value_counts(normalize = True)*100)[:2],data = df,explode = [0,.01],labels = ['survived','death'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax2.pie((df.groupby('alone')['survived'].value_counts(normalize = True)*100)[2:],data = df,explode = [0,.01],labels = ['death','survived'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax1.set_title("Family")
ax2.set_title("alone")

# %%
df.groupby('survived')['alone'].value_counts(normalize = True)*100

# %%
fig,(ax1,ax2) = plt.subplots(ncols = 2,figsize  =(20,10))
ax1.pie((df.groupby('survived')['alone'].value_counts(normalize = True)*100)[:2],data = df,explode = [0,.01],labels = ['alone','Family'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax2.pie((df.groupby('survived')['alone'].value_counts(normalize = True)*100)[2:],data = df,explode = [0,.01],labels = ['Family','alone'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax1.set_title('death')
ax2.set_title('survived')

# %% [markdown]
# alone people dead more and families survived more

# %% [markdown]
# # SIB SP

# %%
df.columns

# %%
df['sibsp'].unique()

# %%
df['sibsp'].value_counts(dropna = False)

# %%
df['sibsp'].value_counts(normalize = True)*100

# %%
sns.boxplot(x = 'sibsp',data = df)

# %%
sns.countplot(x = 'sibsp',data = df)

# %%
sns.countplot(x = 'sibsp',data = df,hue = 'survived')

# %%
plt.pie(x = df['sibsp'].value_counts(normalize = True)*100,data = df,explode = [0,.1,.01,.1,.01,.1,.2],labels = [' 0','1','2', '3', '4',  '5', '8'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")

# %%
df.groupby('sibsp')['survived'].value_counts(normalize = True)*100

# %%
fig,(ax1,ax2,ax3,ax4,ax5,ax6,ax7) = plt.subplots(ncols = 7,figsize  =(20,10))
ax1.pie((df.groupby('sibsp')['survived'].value_counts(normalize = True)*100)[:2],data = df,explode = [0,.01],labels = ['death','survived'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax2.pie((df.groupby('sibsp')['survived'].value_counts(normalize = True)*100)[2:4],data = df,explode = [0,.01],labels = ['survived','death'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax3.pie((df.groupby('sibsp')['survived'].value_counts(normalize = True)*100)[4:6],data = df,explode = [0,.01],labels = ['death','survived'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax4.pie((df.groupby('sibsp')['survived'].value_counts(normalize = True)*100)[6:8],data = df,explode = [0,.01],labels = ['death','survived'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax5.pie((df.groupby('sibsp')['survived'].value_counts(normalize = True)*100)[8:10],data = df,explode = [0,.01],labels = ['death','survived'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax6.pie((df.groupby('sibsp')['survived'].value_counts(normalize = True)*100)[10:11],data = df,explode = [0],labels = ['death'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax7.pie((df.groupby('sibsp')['survived'].value_counts(normalize = True)*100)[11:],data = df,explode = [0],labels = ['death'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax1.set_title("alone")
ax2.set_title("single")
ax3.set_title("2 sibling")
ax4.set_title("3 sibling")
ax5.set_title("4 sibling")
ax6.set_title("5 sibling")
ax7.set_title("8 sibling")

# %%
df.groupby('survived')['sibsp'].value_counts(normalize = True)*100

# %%
fig,(ax1,ax2) = plt.subplots(ncols = 2,figsize  =(20,10))
ax1.pie((df.groupby('survived')['sibsp'].value_counts(normalize = True)*100)[:7],data = df,explode = [0,.1,.01,.1,.01,.1,.2],labels = ['0','1','2','4','3','5','8'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax2.pie((df.groupby('survived')['sibsp'].value_counts(normalize = True)*100)[7:],data = df,explode = [0,.01,.1,.01,.2],labels = ['0','1','2','3','4'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax1.set_title('death')
ax2.set_title('survived')

# %% [markdown]
# # PARCH

# %%
df['parch'].unique()

# %%
df['parch'].value_counts()

# %%
df['parch'].value_counts(normalize = True)*100

# %%
sns.countplot(x  = 'parch',data = df)

# %%
plt.pie(x=df['parch'].value_counts(normalize = True)*100,data = df,explode = [0,.1,.01,1,.01,1,.2],labels = ['0','1','2','3','4','5','6'],textprops= {"fontsize":8},autopct= "%.2f%%")

# %%
sns.countplot(x = 'parch',data = df,hue = 'survived')

# %%
df.groupby('parch')['survived'].value_counts(normalize = True)*100

# %%
fig,(ax1,ax2,ax3,ax4,ax5,ax6,ax7) = plt.subplots(ncols = 7,figsize  =(20,10))
ax1.pie((df.groupby('parch')['survived'].value_counts(normalize = True)*100)[:2],data = df,explode = [0,.01],labels = ['death','survived'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax2.pie((df.groupby('sibsp')['survived'].value_counts(normalize = True)*100)[2:4],data = df,explode = [0,.01],labels = ['survived','death'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax3.pie((df.groupby('sibsp')['survived'].value_counts(normalize = True)*100)[4:6],data = df,explode = [0,.01],labels = ['survived','death'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax4.pie((df.groupby('sibsp')['survived'].value_counts(normalize = True)*100)[6:8],data = df,explode = [0,.01],labels = ['survived','death'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax5.pie((df.groupby('sibsp')['survived'].value_counts(normalize = True)*100)[8:9],data = df,explode = [0],labels = ['death'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax6.pie((df.groupby('sibsp')['survived'].value_counts(normalize = True)*100)[9:11],data = df,explode = [0,.01],labels = ['death','survived'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax7.pie((df.groupby('sibsp')['survived'].value_counts(normalize = True)*100)[11:],data = df,explode = [0],labels = ['death'],shadow = True,textprops= {"fontsize":8},autopct= "%.2f%%")
ax1.set_title("alone")
ax2.set_title("single")
ax3.set_title("2 sibling")
ax4.set_title("3 sibling")
ax5.set_title("4 sibling")
ax6.set_title("5 sibling")
ax7.set_title("6 sibling")

# %%
df.groupby('survived')['parch'].value_counts(normalize = True)*100

# %%
fig,(ax1,ax2) = plt.subplots(ncols = 2,figsize  =(20,10))
ax1.pie((df.groupby('survived')['parch'].value_counts(normalize = True)*100)[:7],data = df,explode = [0,.1,.01,.1,.01,.1,.2],labels = ['0','1','2','4','5','3','6'],textprops= {"fontsize":8},autopct= "%.2f%%")
ax2.pie((df.groupby('survived')['parch'].value_counts(normalize = True)*100)[7:],data = df,explode = [0,.01,.1,.01,.2],labels = ['0','1','2','3','5'],textprops= {"fontsize":8},autopct= "%.2f%%")
ax1.set_title('death')
ax2.set_title('survived')

# %% [markdown]
# # AGE

# %%
df['age'].unique()

# %%
df['age'].value_counts(normalize = True)*100

# %%
df['age'].describe()

# %%
sns.boxplot(x = 'age',data = df)

# %%
sns.histplot(x = 'age',data = df,kde = True,bins = 20 )

# %%
sns.histplot(x = 'age',data = df,kde = True,hue = 'survived',bins = 20 )

# %%
sns.boxplot(data = df,x = 'survived',y = 'age')

# %%
sns.histplot(x = 'age',data = df,kde = True,hue='survived')

# %%
sns.kdeplot(x  = 'age',hue = 'survived',data = df,shade = True)

# %%
df.groupby('survived')['age'].describe()

# %%
(df.groupby('survived')['age'].value_counts(normalize = True)*100)

# %% [markdown]
# infants and adults survived more

# %% [markdown]
# # FARE

# %%
sns.boxplot(x = 'fare',data = df)

# %%
sns.histplot(x= 'fare',data = df,kde = True)

# %%
df['fare'].describe()

# %%
sns.boxplot(x = 'survived',y = 'fare',data = df)

# %%
sns.histplot(x= 'fare',data = df,hue = 'survived',kde = True,binwidth =50 )

# %%
df.groupby('survived')['fare'].describe()

# %% [markdown]
# higher fare paid people survived more
