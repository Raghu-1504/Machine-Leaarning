# %% [markdown]
# <a href="https://www.kaggle.com/code/pyliraghuram/logesticregression-k-foldcv?scriptVersionId=144346951" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/social-network-/Social_Network_Ads.csv')
df.head(4)

# %%
df.info()

# %%
df.describe()

# %%
df.describe(include = 'O')

# %%
sns.heatmap(df.corr(),annot = True)

# %%
df.drop('User ID',axis = 1,inplace = True)

# %%
df.head()

# %% [markdown]
# # **Data Split¶

# %%
y = df['Purchased']
y

# %%
X = df.drop('Purchased',axis = 1)
X

# %% [markdown]
# # Split test and train

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state = 2)

# %% [markdown]
# # Label transformation

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X_train['Gender'] = le.fit_transform(X_train['Gender'])
X_test['Gender'] = le.fit_transform(X_test['Gender'])

# %%
X_train

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

#from sklearn.preprocessing import Normalizer
 
ssc = StandardScaler()
X_train= ssc.fit_transform(X_train)
X_test = ssc.transform(X_test)

# %%
X_train

# %% [markdown]
# # using K - Fould CrossValidation

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression 
log = LogisticRegression()
score = cs = cross_val_score(log,X_train, y_train,cv = 5, scoring='accuracy')
print("Cross-validation scores:", score*100)
np.std(score)*100,np.mean(score)*100

# %% [markdown]
# # MODEL Training

# %%
log.fit(X_train, y_train)
print(log.score(X_train,y_train)*100)

# %%
log.predict_proba(X_test)

# %%
predictions  = log.predict(X_test)
predictions

# %%
y_test.values

# %%
print('test analysis',log.score(X_test,y_test)*100)

# %%
from sklearn.metrics import confusion_matrix, classification_report
confusion_matrix(y_test,predictions)

# %%
print (classification_report(predictions,y_test))

# %%
a = ['purchase','not purchased']

# %%
c = classification_report(predictions,y_test,target_names = a,output_dict=True)
c

# %%
pd.DataFrame(c).T
